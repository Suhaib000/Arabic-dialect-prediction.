# %%
import re
import pandas as pd
def text_preprocessing(text):

        
    """
    - Remove entity mentions (eg. '@united')
    - Correct errors (eg. '&amp;' to '&')
    @param    text (str): a string to be processed.
    @return   text (Str): the processed string.
    """
    
    # Remove'@name'
    text = re.sub("@\S+", '', text)
    # Remove punctuation
    text = re.sub('[!"#$%&\'()*+,-./:;<=>?[\]^_`{|}~]','',text)
    #Remove URLs
    text = re.sub('^https?:\/\/.*[\r\n]*', '', text)
    #Remove emoji 
    text = re.sub("[" u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002702-\U000027B0"
                                u"\U00002500-\U00002BEF"  # chinese char
                                   u"\U00002702-\U000027B0"
                                   u"\U000024C2-\U0001F251"
                                   u"\U0001f926-\U0001f937"
                                   u"\U00010000-\U0010ffff"
                                   u"\u2640-\u2642"
                                   u"\u2600-\u2B55"
                                   u"\u200d"
                                   u"\u23cf"
                                   u"\u23e9"
                                   u"\u231a"
                                   u"\ufe0f"  # dingbats
                                   u"\u3030"
                               u"\U000024C2-\U0001F251"
                               "]+", '', text)
    # replcae (أ,آ,إ) by (ا)
    text = re.sub('[أإآ]', 'ا', text)
    # replace (ة) by (ه)
    text = re.sub('[ة]', 'ه', text)
    text = text.replace('هه', 'ه')
    text = text.replace('وو', 'و')
    text = text.replace('يي', 'ي')
    text = text.replace('اا', 'ا')
    # remove multi spaces
    text = re.sub(' +', ' ', text)
    return text

# %%
DF_new = pd.read_csv("../Data/Data.csv")
DF_new.head()
# Out:
#    Unnamed: 0                                               text dialect
# 0           0   @Nw8ieJUwaCAAreT لكن بالنهاية .. ينتفض .. يغير .      IQ
# 1           1  @7zNqXP0yrODdRjK يعني هذا محسوب على البشر .. ح...      IQ
# 2           2                    @KanaanRema مبين من كلامه خليجي      IQ
# 3           3         @HAIDER76128900 يسلملي مرورك وروحك الحلوه💐      IQ
# 4           4                 @hmo2406 وين هل الغيبه  اخ محمد 🌸🌺      IQ

# %%
DF_new['clean_text'] = DF_new['text'].apply(text_preprocessing)
DF_new.head()
# Out:
#    Unnamed: 0                                               text dialect  \
# 0           0   @Nw8ieJUwaCAAreT لكن بالنهاية .. ينتفض .. يغير .      IQ
# 1           1  @7zNqXP0yrODdRjK يعني هذا محسوب على البشر .. ح...      IQ
# 2           2                    @KanaanRema مبين من كلامه خليجي      IQ
# 3           3         @HAIDER76128900 يسلملي مرورك وروحك الحلوه💐      IQ
# 4           4                 @hmo2406 وين هل الغيبه  اخ محمد 🌸🌺      IQ
#
#                                           clean_text
# 0                           لكن بالنهايه ينتفض يغير
# 1   يعني هذا محسوب على البشر حيونه وحشيه وتطلبون ...
# 2                                مبين من كلامه خليجي
# 3                          يسلملي مرورك وروحك الحلوه
# 4                             وين هل الغيبه اخ محمد

# %%
DF_new.to_csv('../Data/clean_df.csv',index=False)
